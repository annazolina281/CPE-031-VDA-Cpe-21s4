# %% [markdown]
# <a href="https://colab.research.google.com/github/annazolina281/CPE-031-VDA-Cpe-21s4/blob/main/Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

data = {
    'apples': [3, 2, 0, 1],
    'oranges': [0, 3, 7, 2]
}

purchases = pd.DataFrame(data)

print(purchases)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
import pandas as pd

data = {
    'apples': [3, 2, 0, 1],
    'oranges': [0, 3, 7, 2]
}

purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])

print(purchases)
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchases.to_csv('fruits.csv')

# %%
purchases.to_excel('fruits.xlsx')

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd

data = pd.read_csv('fruits.csv')
purchases = pd.DataFrame(data)
print(purchases)
# Out:
#      <input type="file" id="files-1e7d9ff3-5003-4308-9c51-7675edca1101" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e7d9ff3-5003-4308-9c51-7675edca1101">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# LOADING THE DATA FROM EXCEL FILE INTO DATAFRAME

# %%
#Loading the data from excel file

data = pd.read_excel('fruits.xlsx')
purchases = pd.DataFrame(data)
print(purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
data.head(3)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7

# %%
data.tail(3)
# Out:
#   Unnamed: 0  apples  oranges
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %% [markdown]
# EXERCISE 7: Laboratory: Creating and Accessing Panda DataFrames

# %%
#READING DATA FROM CSV

from google.colab import files
uploaded = files.upload()

import pandas as pd
data = pd.read_csv('dataset.csv')
# Out:
#      <input type="file" id="files-94616211-3fc0-4a44-96d8-84300bf2d156" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94616211-3fc0-4a44-96d8-84300bf2d156">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.DataFrame(data)
(dataset)
# Out:
#                                                song\n  \
# 0                                     Blinding Lights
# 1                                   Someone You Loved
# 2       Sunflower - Spider-Man: Into the Spider-Verse
# 3                           STAY (with Justin Bieber)
# 4                                             Starboy
# 5                                          Heat Waves
# 6                                           As It Was
# 7                                     Sweater Weather
# 8                                             Riptide
# 9                                        Another Love
# 10                                             Yellow
# 11                                        Die For You
# 12                                       Viva La Vida
# 13                                    Me Porto Bonito
# 14              Quevedo: Bzrp Music Sessions, Vol. 52
# 15                                        Blank Space
# ...

# %%
import pandas as pd
data = {
    'song': [
        'Blinding Lights',
        'Someone You Loved',
        'Sunflower',
        'STAY(with Justin Bieber)',
        'Starboy'
    ],
    'artist(s)_name': [
        'The Weeknd',
        'Lewis Capaldi',
        'Post Malone, Swae Lee',
        'Justin Bieber, The Kid Laroi',
        'The Weeknd, Daft Punk'
    ],
    'streams': [
        3703895074,
        2887241814,
        2808096550,
        2665343922,
        2565529693
    ]
}

df = pd.DataFrame(data)
(df)
# Out:
#                        song                artist(s)_name     streams
# 0           Blinding Lights                    The Weeknd  3703895074
# 1         Someone You Loved                 Lewis Capaldi  2887241814
# 2                 Sunflower         Post Malone, Swae Lee  2808096550
# 3  STAY(with Justin Bieber)  Justin Bieber, The Kid Laroi  2665343922
# 4                   Starboy         The Weeknd, Daft Punk  2565529693

# %%
import pandas as pd

data = [
    {
        'song': 'Blinding Lights',
        'artist(s)_name': 'The Weeknd',
        'streams': 3703895074
    },
    {
        'song': 'Someone You Loved',
        'artist(s)_name': 'Lewis Capaldi',
        'streams': 2887241814
    },
    {
        'song': 'Sunflower - Spider-Man: Into the Spider-Verse',
        'artist(s)_name': 'Post Malone, Swae Lee',
        'streams': 2808096550
    },
    {
        'song': 'STAY (with Justin Bieber)',
        'artist(s)_name': 'Justin Bieber, The Kid Laroi',
        'streams': 2665343922
    },
    {
        'song': 'Starboy',
        'artist(s)_name': 'The Weeknd, Daft Punk',
        'streams': 2565529693
    }
]

df = pd.DataFrame(data)
(df)
# Out:
#                                             song  \
# 0                                Blinding Lights
# 1                              Someone You Loved
# 2  Sunflower - Spider-Man: Into the Spider-Verse
# 3                      STAY (with Justin Bieber)
# 4                                        Starboy
#
#                  artist(s)_name     streams
# 0                    The Weeknd  3703895074
# 1                 Lewis Capaldi  2887241814
# 2         Post Malone, Swae Lee  2808096550
# 3  Justin Bieber, The Kid Laroi  2665343922
# 4         The Weeknd, Daft Punk  2565529693

# %%
single_column = df['song']
(single_column)
# Out:
# 0                                  Blinding Lights
# 1                                Someone You Loved
# 2    Sunflower - Spider-Man: Into the Spider-Verse
# 3                        STAY (with Justin Bieber)
# 4                                          Starboy
# Name: song, dtype: object

# %%
multiple_column = df[['song', 'artist(s)_name', 'streams']]
(multiple_column)
# Out:
#                                             song  \
# 0                                Blinding Lights
# 1                              Someone You Loved
# 2  Sunflower - Spider-Man: Into the Spider-Verse
# 3                      STAY (with Justin Bieber)
# 4                                        Starboy
#
#                  artist(s)_name     streams
# 0                    The Weeknd  3703895074
# 1                 Lewis Capaldi  2887241814
# 2         Post Malone, Swae Lee  2808096550
# 3  Justin Bieber, The Kid Laroi  2665343922
# 4         The Weeknd, Daft Punk  2565529693

# %%
single_row_pandas = df.loc[2]
single_row_pandas
# Out:
# song              Sunflower - Spider-Man: Into the Spider-Verse
# artist(s)_name                            Post Malone, Swae Lee
# streams                                              2808096550
# Name: 2, dtype: object

# %%
multiple_rows_pandas = df.loc[1:4]
multiple_rows_pandas
# Out:
#                                             song  \
# 1                              Someone You Loved
# 2  Sunflower - Spider-Man: Into the Spider-Verse
# 3                      STAY (with Justin Bieber)
# 4                                        Starboy
#
#                  artist(s)_name     streams
# 1                 Lewis Capaldi  2887241814
# 2         Post Malone, Swae Lee  2808096550
# 3  Justin Bieber, The Kid Laroi  2665343922
# 4         The Weeknd, Daft Punk  2565529693
